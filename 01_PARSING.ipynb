# %%
# !pip install pandas python-docx pdfplumber openpyxl xlrd
# Out:
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: python-docx in c:\users\user\anaconda3\lib\site-packages (1.2.0)
# Requirement already satisfied: pdfplumber in c:\users\user\anaconda3\lib\site-packages (0.11.9)
# Requirement already satisfied: openpyxl in c:\users\user\anaconda3\lib\site-packages (3.1.5)
# Requirement already satisfied: xlrd in c:\users\user\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: lxml>=3.1.0 in c:\users\user\anaconda3\lib\site-packages (from python-docx) (5.3.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\user\anaconda3\lib\site-packages (from python-docx) (4.12.2)
# Requirement already satisfied: pdfminer.six==20251230 in c:\users\user\anaconda3\lib\site-packages (from pdfplumber) (20251230)
# Requirement already satisfied: Pillow>=9.1 in c:\users\user\anaconda3\lib\site-packages (from pdfplumber) (11.1.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in c:\users\user\anaconda3\lib\site-packages (from pdfplumber) (5.3.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from pdfminer.six==20251230->pdfplumber) (3.3.2)
# Requirement already satisfied: cryptography>=36.0.0 in c:\users\user\anaconda3\lib\site-packages (from pdfminer.six==20251230->pdfplumber) (44.0.1)
# Requirement already satisfied: et-xmlfile in c:\users\user\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\user\anaconda3\lib\site-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\user\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
def clovaOCR(image_path: str) -> dict:
    """
    TODO: CLOVA OCR 호출(이미지 또는 스캔 PDF)
    content 스키마에 맞춰 반환
    """
    return {
        "pageCount": 1,
        "pages": {
            "page1": {
                "text": "",
                "tableCount": 1,
                "tables": {
                    "table1": {
                        "rows": [],
                        "rowCount": 0,
                        "colCount": 0
                    }
                }
            }
        }
    }

# %%
# 표처리 헬퍼
def clean_table(tbl):   
    return [
        [c for c in ("" if c is None else str(c).strip() for c in row) if c]
        for row in tbl
        if any("" if c is None else str(c).strip() for c in row)
    ]

# %%
# 파일별 파싱 함수
from pathlib import Path
import pandas as pd
from docx import Document
import pdfplumber

CSV_EXT = {"csv"}
EXCEL_EXT = {"xls", "xlsx"}
IMAGE_EXT = {"jpg", "png"}
OTHER_EXT = {"pdf", "docx"}

def handle_csv(path: str):
    for enc in ["cp949", "euc-kr", "utf-8"]:
        try:
            df = pd.read_csv(path, encoding=enc)
            return {"kind": "CSV", "ext": "csv", "dataframe": df}
        except UnicodeDecodeError:
            continue
    raise ValueError("인코딩 실패: cp949, euc-kr, utf-8 encoding을 지원합니다")

def handle_excel(path: str, ext: str):
    df = pd.read_excel(path)
    return {"kind": "EXCEL", "ext": ext, "dataframe": df}

def handle_image(path: str, ext: str):
    ocr_output = clovaOCR(path)
    return {"kind": "IMAGE", "ext": ext, "content": ocr_output}

def clean_table(tbl):
    return [
        [c for c in ("" if c is None else str(c).strip() for c in row) if c]
        for row in tbl
        if any("" if c is None else str(c).strip() for c in row)
    ]

def handle_pdf(path: str, ext: str):
    PDF_PAGE_MIN_CHARS = 30
    PDF_PASS_RATIO = 0.7

    with pdfplumber.open(path) as pdf:
        total_pages = len(pdf.pages)
        valid_page_count = 0
        pages_data = {}

        for i, page in enumerate(pdf.pages):
            t = page.extract_text() or ""
            clean_t = " ".join(t.split()).strip()
            if len(clean_t) >= PDF_PAGE_MIN_CHARS: valid_page_count += 1
            raw = page.extract_tables() or []
            tables = {f"table{ti+1}": (lambda rows: {"rows": rows, "rowCount": len(rows), "colCount": max((len(r) for r in rows), default=0)})(clean_table(tbl)) for ti, tbl in enumerate(raw)}
            pages_data[f"page{i+1}"] = {"text": clean_t, "tableCount": len(raw), "tables": tables}

        pass_ratio = valid_page_count / max(total_pages, 1)

    if pass_ratio >= PDF_PASS_RATIO: return {"kind":"PDF","ext":ext,"mode":"text","pass_ratio":pass_ratio,"content":{"pageCount":total_pages,"pages":pages_data}}
    else:
        ocr_output = clovaOCR(path)
        return {"kind": "PDF", "ext": ext, "mode": "ocr", "content": ocr_output}

def handle_docx(path: str, ext: str):
    doc = Document(path)
    paragraphs = [p.text.strip() for p in doc.paragraphs if p.text.strip()]
    tables = {}
    for i, table in enumerate(doc.tables, start=1):
        rows = [[cell.text for cell in row.cells] for row in table.rows]
        tables[f"table{i}"] = {
            "rows": rows,
            "rowCount": len(rows),
            "colCount": max((len(r) for r in rows), default=0),
        }
    pages = {
        "page1": {
            "text": "\n".join(paragraphs),
            "tableCount": len(doc.tables),
            "tables": tables,
        }
    }
    return {"kind": "DOCX", "ext": ext, "content": {"pageCount": 1, "pages": pages}}

# %%
# 파일 형식별 조건부 함수구동
def handle_file(path: str):
    ext = Path(path).suffix.lower().lstrip(".")
    if ext in CSV_EXT: return handle_csv(path)
    if ext in EXCEL_EXT: return handle_excel(path, ext)
    if ext in IMAGE_EXT: return handle_image(path, ext)
    if ext == "pdf": return handle_pdf(path, ext)
    if ext == "docx": return handle_docx(path, ext)
    raise ValueError(f"지원하지 않는 파일 형식입니다: {ext}")

# %%
# docx 테스트
path = "C:/Users/User/Downloads/현대협력_ESG_진단_산출물_진단서_위험군보고서.docx"
test_result = handle_file(path)
test_result
# Out:
# {'kind': 'DOCX',
#  'ext': 'docx',
#  'content': {'pageCount': 1,
#   'pages': {'page1': {'text': '공급망 ESG 진단 산출물\n(진단서 + 위험군 보고서)\n※ 이 문서는 실제 제출용이 아닌 시연용(임시) 예시입니다. 실제 서비스에서는 업종/규모/증빙 업로드 결과에 따라 항목·결과가 자동 생성됩니다.\n목차\n위험군 보고서\n진단서\n1. 위험군 보고서\n1.1 등급\n종합 등급 : B (중 위험군)\n판정 근거(요약): 필수 항목 중 미충족 3건 및 미확인/누락 다수 존재\n1.2 결과(10줄 이상, 세부)\n정성 체크리스트 25개 중 충족 6개, 부분충족 11개, 미충족 3개, 미확인 5개로 집계됨(샘플).\n인권·노동 영역에서 차별·괴롭힘 금지 및 신고채널 운영이 미충족으로 확인되어 인권 리스크가 상향됨.\n강제노동 금지 절차는 일부 존재하나(부분충족), 해외/이주노동자 관련 증빙이 없어 검증 강도가 낮음.\n근로시간 관리는 일부 기록으로 확인되나, 초과근로 통제(사전 승인/상한 관리) 체계가 불충분함.\n안전보건 영역에서 산업재해·아차사고 보고/재발방지 프로세스가 미충족으로 확인되어 중대사고 예방 체계가 취약함.\n위험성평가는 일부 수행 기록이 있으나, 개선조치 이행 증빙(CAPA 완료 증빙)이 부족하여 효과 검증이 어려움.\n외주/협력 인력의 안전교육 이수율 데이터가 누락되어, 현장 작업자 전체에 대한 안전 통제가 확인되지 않음.\n환경 영역은 폐기물 인계서로 기본 준수는 확인되지만, 인허가·법정 측정 성적서가 미제출되어 규제 리스크를 정량 평가하기 어려움.\n온실가스(Scope 1+2) 및 용수 사용량 등 핵심 환경 데이터가 누락되어, 고객사 요구 또는 공시 대응에 제약이 발생할 수 있음.\n윤리·컴플라이언스 영역에서 부패방지 정책은 있으나, 승인/기록 절차가 미흡하고 교육 이수율(60%)이 낮아 잔존 리스크가 존재함.\n정보보안 영역에서 보안사고 대응 및 백업 정책이 미충족이며, 백업 주기 데이터도 누락되어 운영중단·데이터 손실 리스크가 큼.\n정량 항목 25개 중 누락 10개, 불확실 8개로 데이터 완성도가 낮아, 등급 산정 시 보수적으로(리스크 상향) 반영됨.\n1.3 핵심 리스크 요인 Top 5\n1.4 개선 권고(피드백)\n1.5 누락/불확실 데이터 목록\n2. 진단서\n2.1 진단 개요\n2.2 정성적 진단(체크리스트)\n정성 요약(3줄 이내)\n익명 신고채널 및 신고자 보호 절차를 지키지 않음.\n산업재해·아차사고 조사 및 재발방지 프로세스를 지키지 않음.\n보안사고 대응 및 백업 정책(랜섬웨어 대비)을 지키지 않음.\n2.3 정량적 진단(지표/수치)',
#     'tableCount': 8,
#     'tables': {'table1': {'rows': [['원청사명', '현대중공업'],
#        ['협력사명', '현대협력'],
#        ['작성일', '2026-01-14'],
#        ['문서버전', 'v0.1'],
#        ['산출물 구성', '1) 위험군 보고서 2) 진단서'],
#        ['비고', '본 문서는 데모/샘플 데이터로 작성됨']],
#       'rowCount': 6,
#       'colCount': 2},
#      'table2': {'rows': [['종합 점수', '68 / 100'],
#        ['정성 점수', '38 / 60'],
#        ['정량 점수', '30 / 40']],
#       'rowCount': 3,
#       'colCount': 2},
#      'table3': {'rows': [['순위', '리스크 요인', '근거(연관 항목)', '영향도', '긴급도'],
#        ['1',
#         '보안사고 대응 및 백업 정책 부재',
#         '정성-정보보안(미충족), 정량 QN-22(누락)',
#         '매우 높음',
#         '높음'],
#        ['2', '산업재해/아차사고 재발방지 체계 미흡', '정성-안전보건(미충족), 정량 QN-03(누락)', '높음', '높음'],
#        ['3', '익명 신고채널·보호 절차 미흡', '정성-인권(미충족), 정량 QN-17(누락)', '높음', '중간'],
#        ['4', '온실가스 배출량 산정 데이터 누락', '정량 QN-07(누락), 에너지 모니터링(부분충족)', '중간', '중간'],
#        ['5',
#         '2차 협력사 ESG 평가/개선 추적 미흡',
#         '정성-공급망(부분충족/미확인), 정량 QN-19~20(누락)',
#         '중간',
#         '중간']],
#       'rowCount': 6,
#       'colCount': 5},
#      'table4': {'rows': [['권고ID',
#         '권고 내용',
#         '관련 리스크',
#         '우선순위',
#         '권장 기한',
#         '담당(예시)'],
#        ['R-01',
#         '익명 신고채널(웹/전화) 구축 및 신고자 보호 절차(비밀보장·불이익 금지·처리기한) 문서화',
#         '인권/윤리',
#         '최상',
#         '30일',
#         '현대협력'],
#        ['R-02',
#         '산업재해·아차사고 보고-조사-재발방지 표준 프로세스 수립(원인분석, CAPA, 재발검증 포함)',
#         '안전보건',
#         '최상',
#         '45일',
#         '현대협력'],
#        ['R-03',
#         '백업 정책 수립(대상/주기/보관/복구 테스트) 및 랜섬웨어 대응 계획(격리/권한/훈련) 마련',
#         '정보보안',
#         '최상',
#         '45일',
#         '현대협력'],
#        ['R-04',
#         '외주/협력 인력 포함 안전교육 관리(출입-교육 연계, 미이수 차단) 및 이수율 100% 달성',
#         '안전보건',
#         '상',
#         '60일',
#         '현대협력'],
#        ['R-05',
#         '권한 부여/회수 승인 흐름 및 이력 로그 확보(분기 점검 포함)',
#         '개인정보/보안',
#         '상',
#         '60일',
#         '현대협력'],
#        ['R-06',
#         '환경 인허가·법정 측정 성적서 제출 체계 구축 및 법규 목록 최신화',
#         '환경',
#         '상',
#         '60일',
#         '현대협력'],
#        ['R-07',
#         '온실가스(Scope1+2) 산정 경계 정의 후 월별 데이터 수집(전력/연료) 및 산정표 작성',
#         '환경',
#         '중',
#         '90일',
#         '현대협력'],
#        ['R-08',
#         '부패방지/정보보안 교육 이수율 100% 달성(미이수자 자동 알림·재교육) 및 교육 기록 보관',
#         '윤리/보안',
#         '중',
#         '90일',
#         '현대협력'],
#        ['R-09',
#         '2차 협력사 등록-평가-개선조치 추적 프로세스 수립(평가 기준·주기·반려 기준 포함)',
#         '공급망',
#         '중',
#         '90일',
#         '현대협력+현대중공업'],
#        ['R-10',
#         '정량 데이터(에너지/폐기물/교육/사고) 월별 집계 템플릿 표준화 및 증빙 업로드 규칙 적용',
#         '데이터 품질',
#         '중',
#         '60일',
#         '현대협력']],
#       'rowCount': 11,
#       'colCount': 6},
#      'table5': {'rows': [['항목ID', '항목', '상태', '사유(예시)', '요청 증빙/데이터(예시)'],
#        ['QN-03',
#         '아차사고 보고 건수',
#         '누락',
#         '보고 체계/기록 미제출',
#         '아차사고 보고서(최근 12개월), 보고 프로세스 문서'],
#        ['QN-05',
#         '외주/협력 인력 안전교육 이수율',
#         '누락',
#         '외주 포함 집계 불가',
#         '출입명부+교육이수 연계 데이터, 외주 교육대장'],
#        ['QN-07',
#         '온실가스 배출량(Scope1+2)',
#         '누락',
#         '산정표/활동자료 미제출',
#         '전력·연료 사용 데이터, 산정 경계 정의, 산정표'],
#        ['QN-08', '용수 사용량', '누락', '계량/청구서 미제출', '수도요금 청구서 또는 계량기 기록'],
#        ['QN-11',
#         '폐기물 재활용률',
#         '불확실',
#         '분류별 집계표 부재',
#         '폐기물 분류별 발생/재활용 집계표, 위탁처리 명세'],
#        ['QN-13',
#         '환경 법규 위반/행정처분',
#         '누락',
#         '공식 확인 자료 미제출',
#         '최근 3년 행정처분 확인서(없음 포함)'],
#        ['QN-17',
#         '익명 신고 접수 건수',
#         '누락',
#         '채널 미운영 추정',
#         '신고채널 운영 증빙(URL/전화), 처리대장(익명화)'],
#        ['QN-19',
#         '협력사 ESG 평가 실시 비율',
#         '누락',
#         '평가 기록 미제출',
#         '평가표, 평가 결과, 평가 주기·기준'],
#        ['QN-22', '백업 수행 주기', '누락', '정책/로그 미제출', '백업 정책, 백업 로그, 복구 테스트 결과'],
#        ['QN-25',
#         '개인정보 파기 기록 보관율',
#         '누락',
#         '파기대장 미제출',
#         '파기대장, 파기 절차서, 파기 증빙(스크린샷 등)']],
#       'rowCount': 11,
#       'colCount': 5},
#      'table6': {'rows': [['진단 대상', '현대협력 (현대중공업 협력사, 샘플)'],
#        ['진단 범위', '인권·노동 / 안전보건 / 환경 / 윤리·컴플라이언스 / 공급망 관리 / 정보보안·개인정보'],
#        ['진단 방식', '정성(체크리스트) + 정량(지표/수치)'],
#        ['상태 정의(정성)', '충족 / 부분충족 / 미충족 / 미확인'],
#        ['상태 정의(정량)', '확인 / 누락 / 불확실'],
#        ['근거 유형', '정책·절차 문서 / 교육·점검 기록 / 시스템 로그 / 제3자 인증 / 미제출(확인 불가)']],
#       'rowCount': 6,
#       'colCount': 2},
#      'table7': {'rows': [['No', '구분', '체크항목', '요구수준', '응답', '근거(예시)', '비고'],
#        ['1', '인권·노동', '아동노동 금지 정책 및 계약서 반영', '필수', '충족', '인권정책 v1.0', '-'],
#        ['2',
#         '인권·노동',
#         '강제노동 금지(채무노동 포함) 확인 절차',
#         '필수',
#         '부분충족',
#         '채용절차서 일부',
#         '해외근로자 증빙 미흡'],
#        ['3',
#         '인권·노동',
#         '차별·괴롭힘 금지 및 신고채널 운영',
#         '필수',
#         '미충족',
#         '미제출',
#         '익명 제보/보호 절차 부재'],
#        ['4',
#         '인권·노동',
#         '근로시간·휴게시간 준수(법정 기준)',
#         '필수',
#         '부분충족',
#         '근태기록 일부',
#         '초과근로 관리 미흡'],
#        ['5', '인권·노동', '임금·수당 지급 및 체불 방지', '필수', '충족', '급여대장(샘플)', '-'],
#        ['6',
#         '인권·노동',
#         '이주노동자(해당 시) 권리 보호(계약·언어)',
#         '권장',
#         '미확인',
#         '미제출',
#         '해당 여부 확인 필요'],
#        ['7', '인권·노동', '협력업체(2차) 인권 리스크 평가', '권장', '미확인', '미제출', '평가 체계 확인 불가'],
#        ['8',
#         '안전보건',
#         '안전보건 방침/목표(KPI) 수립',
#         '필수',
#         '부분충족',
#         '안전보건 계획서',
#         '정량 KPI 부족'],
#        ['9',
#         '안전보건',
#         '정기 위험성평가 실시 및 개선조치 기록',
#         '필수',
#         '부분충족',
#         '위험성평가표(일부)',
#         '이행 증빙 부족'],
#        ['10', '안전보건', '보호구(PPE) 지급·착용 관리', '필수', '충족', 'PPE 지급대장', '-'],
#        ['11',
#         '안전보건',
#         '산업재해·아차사고 보고/재발방지 프로세스',
#         '필수',
#         '미충족',
#         '미제출',
#         '조사보고서/절차 부재'],
#        ['12',
#         '안전보건',
#         '작업허가서(Hot work 등) 운영',
#         '필수',
#         '부분충족',
#         '작업허가서(일부)',
#         '현장 적용 범위 불명'],
#        ['13',
#         '안전보건',
#         '협력사/외주 작업자 안전교육',
#         '필수',
#         '부분충족',
#         '교육이수 명단(일부)',
#         '외주 이수율 미확인'],
#        ['14',
#         '안전보건',
#         '비상대응(화재/누출) 훈련 및 점검',
#         '권장',
#         '부분충족',
#         '소방점검표',
#         '훈련 기록 불완전'],
#        ['15',
#         '안전보건',
#         '화학물질 누출 대응 절차 및 장비',
#         '필수',
#         '부분충족',
#         'MSDS 일부',
#         '누출키트 점검 기록 부족'],
#        ['16',
#         '환경',
#         '환경경영 방침 및 법규 준수 체계',
#         '필수',
#         '부분충족',
#         '환경관리지침',
#         '법규 목록 최신화 필요'],
#        ['17',
#         '환경',
#         '유해화학물질(보관/취급/누출대응) 관리',
#         '필수',
#         '부분충족',
#         'MSDS 목록(일부)',
#         '창고 점검 기록 부족'],
#        ['18', '환경', '폐기물 분리배출 및 위탁처리 증빙', '필수', '충족', '폐기물 인계서(샘플)', '-'],
#        ['19', '환경', '대기/수질/소음 인허가·측정 기록', '필수', '미확인', '미제출', '측정성적서 미제출'],
#        ['20', '환경', '비상시 환경사고 대응(유출/오염) 계획', '권장', '미확인', '미제출', '계획서 확인 불가'],
#        ['21',
#         '환경',
#         '에너지 사용량 모니터링(월별 집계)',
#         '권장',
#         '부분충족',
#         '전력고지서(일부)',
#         '월별 집계 미흡'],
#        ['22',
#         '윤리·컴플라이언스',
#         '부패방지 정책(금품/접대/리베이트)',
#         '필수',
#         '부분충족',
#         '윤리규정',
#         '승인/기록 절차 부족'],
#        ['23', '윤리·컴플라이언스', '이해상충 신고 및 관리', '권장', '미확인', '미제출', '제도 확인 불가'],
#        ['24',
#         '공급망',
#         '2차 협력사 등록·평가·개선 프로세스',
#         '권장',
#         '부분충족',
#         '협력사 목록',
#         '평가 기준/주기 미정'],
#        ['25',
#         '정보보안·개인정보',
#         '보안사고 대응/백업/랜섬웨어 대비',
#         '필수',
#         '미충족',
#         '미제출',
#         '사고대응·백업정책 부재']],
#       'rowCount': 26,
#       'colCount': 7},
#      'table8': {'rows': [['항목ID',
#         '진단 항목',
#         '단위',
#         '상태',
#         '결과(예시)',
#         '기준/요구',
#         '근거(예시)',
#         '비고'],
#        ['QN-01', '총 근로자 수', '명', '확인', '180', '-', '인사현황표(샘플)', '-'],
#        ['QN-02',
#         '최근 12개월 산업재해 건수',
#         '건',
#         '불확실',
#         '2',
#         '0건 목표(권장)',
#         '산재보고(미제출)',
#         '구두 확인'],
#        ['QN-03',
#         '최근 12개월 아차사고 보고 건수',
#         '건',
#         '누락',
#         '-',
#         '월 1건 이상 보고(권장)',
#         '미제출',
#         '보고 체계 부재 가능'],
#        ['QN-04',
#         '정기 안전교육 평균 이수시간',
#         '시간/인',
#         '확인',
#         '4.5',
#         '연 8시간 이상(예시)',
#         '교육대장(일부)',
#         '외주 포함 필요'],
#        ['QN-05',
#         '외주/협력 인력 안전교육 이수율',
#         '%',
#         '누락',
#         '-',
#         '100%',
#         '미제출',
#         '출입/교육 연동 필요'],
#        ['QN-06',
#         '전력 사용량(연간)',
#         'MWh',
#         '불확실',
#         '1,250',
#         '-',
#         '전기요금 고지서(일부)',
#         '월별 집계 필요'],
#        ['QN-07',
#         '온실가스 배출량(Scope 1+2)',
#         'tCO2e',
#         '누락',
#         '-',
#         '산정 및 보고(권장)',
#         '미제출',
#         '산정 경계 설정 필요'],
#        ['QN-08', '연간 용수 사용량', '톤', '누락', '-', '-', '미제출', '계량기/청구서 필요'],
#        ['QN-09',
#         '일반폐기물 발생량',
#         '톤/년',
#         '확인',
#         '48',
#         '전년 대비 감축(권장)',
#         '인계서(샘플)',
#         '-'],
#        ['QN-10', '지정폐기물 발생량', '톤/년', '확인', '6.2', '법정 준수', '인계서(샘플)', '-'],
#        ['QN-11',
#         '폐기물 재활용률',
#         '%',
#         '불확실',
#         '62',
#         '70% 이상(예시)',
#         '집계표(미제출)',
#         '분류 체계 필요'],
#        ['QN-12',
#         '유해화학물질 취급 교육 이수율',
#         '%',
#         '불확실',
#         '80',
#         '100%',
#         '교육기록(일부)',
#         '명단/주기 확인 필요'],
#        ['QN-13',
#         '환경 법규 위반/행정처분 건수(최근 3년)',
#         '건',
#         '누락',
#         '-',
#         '0건',
#         '미제출',
#         '공식 확인 필요'],
#        ['QN-14', '부패방지 교육 이수율', '%', '확인', '60', '100%', '교육이수 기록(샘플)', '-'],
#        ['QN-15',
#         '윤리/컴플라이언스 서약서 징구율',
#         '%',
#         '확인',
#         '70',
#         '100%',
#         '서약서(일부)',
#         '신규/협력사 포함 필요'],
#        ['QN-16',
#         '내부 점검(감사) 수행 횟수(연간)',
#         '회',
#         '불확실',
#         '1',
#         '2회 이상(예시)',
#         '점검보고(미제출)',
#         '체계화 필요'],
#        ['QN-17',
#         '익명 신고 접수 건수(연간)',
#         '건',
#         '누락',
#         '-',
#         '채널 운영(필수)',
#         '미제출',
#         '채널 미운영 추정'],
#        ['QN-18', '협력사(2차) 등록 수', '개', '확인', '35', '-', '협력사 리스트', '-'],
#        ['QN-19',
#         '협력사 ESG 평가 실시 비율',
#         '%',
#         '누락',
#         '-',
#         '100%(권장)',
#         '미제출',
#         '평가기준/주기 필요'],
#        ['QN-20',
#         '협력사 개선조치 완료율',
#         '%',
#         '누락',
#         '-',
#         '80% 이상(예시)',
#         '미제출',
#         '추적관리 필요'],
#        ['QN-21',
#         '정보보안 교육 이수율',
#         '%',
#         '불확실',
#         '50',
#         '100%',
#         '교육기록(일부)',
#         '전사 확대 필요'],
#        ['QN-22',
#         '백업 수행 주기',
#         '회/주',
#         '누락',
#         '-',
#         '주 1회 이상(예시)',
#         '미제출',
#         '정책/로그 필요'],
#        ['QN-23',
#         '접근권한 점검 주기',
#         '회/년',
#         '불확실',
#         '1',
#         '분기 1회(예시)',
#         '권한표(일부)',
#         '승인·이력 필요'],
#        ['QN-24', '개인정보 처리시스템 보유 여부', 'Y/N', '확인', 'Y', '-', '시스템 목록(샘플)', '-'],
#        ['QN-25', '개인정보 파기 기록 보관율', '%', '누락', '-', '100%', '미제출', '파기대장 필요']],
#       'rowCount': 26,
#       'colCount': 8}}}}}}

# %%
# pdf 테스트
path = "C:/Users/User/Downloads/현대협력_ESG_진단_산출물_진단서_위험군보고서.pdf"
test_result = handle_file(path)
test_result
# Out:
# {'kind': 'PDF',
#  'ext': 'pdf',
#  'mode': 'text',
#  'content': {'pageCount': 10,
#   'pages': {'page1': {'text': '공급망 ESG 진단 산출물\n(진단서 + 위험군 보고서)\n1',
#     'tableCount': 0,
#     'tables': {}},
#    'page2': {'text': '원청사명 현대중공업\n협력사명 현대협력\n작성일 2026-01-14\n문서버전 v0.1\n산출물 구성 1) 위험군 보고서 2) 진단서\n비고 본 문서는 데모/샘플 데이터로 작성됨\n※ 이 문서는 실제 제출용이 아닌 시연용(임시) 예시입니다. 실제 서비스에서는 업종/규모/증빙 업로드\n결과에 따라 항목·결과가 자동 생성됩니다.\n목차\n1. 위험군 보고서\n2. 진단서\n2',
#     'tableCount': 1,
#     'tables': {'table1': {'rows': [['현대중공업'],
#        ['원청사명'],
#        ['현대협력'],
#        ['협력사명'],
#        ['2026-01-14'],
#        ['작성일'],
#        ['v0.1'],
#        ['문서버전'],
#        ['1) 위험군 보고서 2) 진단서'],
#        ['산출물 구성'],
#        ['본 문서는 데모/샘플 데이터로 작성됨'],
#        ['비고']],
#       'rowCount': 12,
#       'colCount': 1}}},
#    'page3': {'text': '1. 위험군 보고서\n1.1 등급\n종합 등급 : B\n(중 위험군)\n종합 점수 68 / 100\n정성 점수 38 / 60\n정량 점수 30 / 40\n판정 근거(요약): 필수 항목 중 미충족 3 건 및 미확인/누락 다수 존재\n1.2 결과(10 줄 이상, 세부)\n1. 정성 체크리스트 25개 중 충족 6개, 부분충족 11개, 미충족 3개, 미확인 5개로 집계됨(샘플).\n2. 인권·노동 영역에서 차별·괴롭힘 금지 및 신고채널 운영이 미충족으로 확인되어 인권 리스크가\n상향됨.\n3. 강제노동 금지 절차는 일부 존재하나(부분충족), 해외/이주노동자 관련 증빙이 없어 검증\n강도가 낮음.\n4. 근로시간 관리는 일부 기록으로 확인되나, 초과근로 통제(사전 승인/상한 관리) 체계가\n불충분함.\n5. 안전보건 영역에서 산업재해·아차사고 보고/재발방지 프로세스가 미충족으로 확인되어\n중대사고 예방 체계가 취약함.\n6. 위험성평가는 일부 수행 기록이 있으나, 개선조치 이행 증빙(CAPA 완료 증빙)이 부족하여\n효과 검증이 어려움.\n7. 외주/협력 인력의 안전교육 이수율 데이터가 누락되어, 현장 작업자 전체에 대한 안전 통제가\n확인되지 않음.\n8. 환경 영역은 폐기물 인계서로 기본 준수는 확인되지만, 인허가·법정 측정 성적서가 미제출되어\n규제 리스크를 정량 평가하기 어려움.\n9. 온실가스(Scope 1+2) 및 용수 사용량 등 핵심 환경 데이터가 누락되어, 고객사 요구 또는 공시\n대응에 제약이 발생할 수 있음.\n10. 윤리·컴플라이언스 영역에서 부패방지 정책은 있으나, 승인/기록 절차가 미흡하고 교육\n이수율(60%)이 낮아 잔존 리스크가 존재함.\n3',
#     'tableCount': 1,
#     'tables': {'table1': {'rows': [['68 / 100'],
#        ['종합 점수'],
#        ['38 / 60'],
#        ['정성 점수'],
#        ['30 / 40'],
#        ['정량 점수']],
#       'rowCount': 6,
#       'colCount': 1}}},
#    'page4': {'text': '11. 정보보안 영역에서 보안사고 대응 및 백업 정책이 미충족이며, 백업 주기 데이터도 누락되어\n운영중단·데이터 손실 리스크가 큼.\n12. 정량 항목 25개 중 누락 10개, 불확실 8개로 데이터 완성도가 낮아, 등급 산정 시\n보수적으로(리스크 상향) 반영됨.\n1.3 핵심 리스크 요인 Top 5\n순위 리스크 요인 근거(연관 항목) 영향도 긴급도\n1 보안사고 대응 및 정성-정보보안(미충족), 매우 높음 높음\n백업 정책 부재 정량 QN-22(누락)\n2 산업재해/아차사고 정성-안전보건(미충족), 높음 높음\n재발방지 체계 미흡 정량 QN-03(누락)\n3 익명 신고채널·보호 정성-인권(미충족), 정량 높음 중간\n절차 미흡 QN-17(누락)\n4 온실가스 배출량 정량 QN-07(누락), 중간 중간\n산정 데이터 누락 에너지\n모니터링(부분충족)\n5 2차 협력사 ESG 정성- 중간 중간\n평가/개선 추적 미흡 공급망(부분충족/미확인),\n정량 QN-19~20(누락)\n1.4 개선 권고(피드백)\n권고ID 권고 내용 관련 리스크 우선순위 권장 담당(예시)\n기한\nR-01 익명 신고채널(웹/전화) 구축 및 인권/윤리 최상 30일 현대협력\n신고자 보호\n절차(비밀보장·불이익\n금지·처리기한) 문서화\nR-02 산업재해·아차사고 보고-조사- 안전보건 최상 45일 현대협력\n재발방지 표준 프로세스\n수립(원인분석, CAPA, 재발검증\n포함)\nR-03 백업 정책 정보보안 최상 45일 현대협력\n4',
#     'tableCount': 2,
#     'tables': {'table1': {'rows': [['순위', '리스크 요인', '근거(연관 항목)', '영향도', '긴급도'],
#        ['1',
#         '보안사고 대응 및\n백업 정책 부재',
#         '정성-정보보안(미충족),\n정량 QN-22(누락)',
#         '매우 높음',
#         '높음'],
#        ['2',
#         '산업재해/아차사고\n재발방지 체계 미흡',
#         '정성-안전보건(미충족),\n정량 QN-03(누락)',
#         '높음',
#         '높음'],
#        ['3', '익명 신고채널·보호\n절차 미흡', '정성-인권(미충족), 정량\nQN-17(누락)', '높음', '중간'],
#        ['4',
#         '온실가스 배출량\n산정 데이터 누락',
#         '정량 QN-07(누락),\n에너지\n모니터링(부분충족)',
#         '중간',
#         '중간'],
#        ['5',
#         '2차 협력사 ESG\n평가/개선 추적 미흡',
#         '정성-\n공급망(부분충족/미확인),\n정량 QN-19~20(누락)',
#         '중간',
#         '중간']],
#       'rowCount': 6,
#       'colCount': 5},
#      'table2': {'rows': [['권고ID', '권고 내용', '관련 리스크', '우선순위', '권장', '담당(예시)'],
#        ['기한'],
#        ['R-01',
#         '익명 신고채널(웹/전화) 구축 및\n신고자 보호\n절차(비밀보장·불이익\n금지·처리기한) 문서화',
#         '인권/윤리',
#         '최상',
#         '30일',
#         '현대협력'],
#        ['R-02',
#         '산업재해·아차사고 보고-조사-\n재발방지 표준 프로세스\n수립(원인분석, CAPA, 재발검증\n포함)',
#         '안전보건',
#         '최상',
#         '45일',
#         '현대협력'],
#        ['R-03', '백업 정책', '정보보안', '최상', '45일', '현대협력']],
#       'rowCount': 5,
#       'colCount': 6}}},
#    'page5': {'text': '수립(대상/주기/보관/복구\n테스트) 및 랜섬웨어 대응\n계획(격리/권한/훈련) 마련\nR-04 외주/협력 인력 포함 안전교육 안전보건 상 60일 현대협력\n관리(출입-교육 연계, 미이수\n차단) 및 이수율 100% 달성\nR-05 권한 부여/회수 승인 흐름 및 개인정보/보안 상 60일 현대협력\n이력 로그 확보(분기 점검 포함)\nR-06 환경 인허가·법정 측정 성적서 환경 상 60일 현대협력\n제출 체계 구축 및 법규 목록\n최신화\nR-07 온실가스(Scope1+2) 산정 경계 환경 중 90일 현대협력\n정의 후 월별 데이터\n수집(전력/연료) 및 산정표 작성\nR-08 부패방지/정보보안 교육 이수율 윤리/보안 중 90일 현대협력\n100% 달성(미이수자 자동\n알림·재교육) 및 교육 기록 보관\nR-09 2차 협력사 등록-평가-개선조치 공급망 중 90일 현대협력+현대중공업\n추적 프로세스 수립(평가\n기준·주기·반려 기준 포함)\nR-10 정량 데이터 품질 중 60일 현대협력\n데이터(에너지/폐기물/교육/사고)\n월별 집계 템플릿 표준화 및 증빙\n업로드 규칙 적용\n1.5 누락/불확실 데이터 목록\n항목ID 항목 상태 사유(예시) 요청\n증빙/데이터(예시)\nQN-03 아차사고 보고 건수 누락 보고 체계/기록 아차사고\n미제출 보고서(최근\n12개월), 보고\n프로세스 문서\nQN-05 외주/협력 인력 누락 외주 포함 집계 불가 출입명부+교육이수\n안전교육 이수율 연계 데이터, 외주\n교육대장\nQN-07 온실가스 누락 산정표/활동자료 전력·연료 사용\n배출량(Scope1+2) 미제출 데이터, 산정 경계\n5',
#     'tableCount': 2,
#     'tables': {'table1': {'rows': [['수립(대상/주기/보관/복구\n테스트) 및 랜섬웨어 대응\n계획(격리/권한/훈련) 마련'],
#        ['R-04',
#         '외주/협력 인력 포함 안전교육\n관리(출입-교육 연계, 미이수\n차단) 및 이수율 100% 달성',
#         '안전보건',
#         '상',
#         '60일',
#         '현대협력'],
#        ['R-05',
#         '권한 부여/회수 승인 흐름 및\n이력 로그 확보(분기 점검 포함)',
#         '개인정보/보안',
#         '상',
#         '60일',
#         '현대협력'],
#        ['R-06',
#         '환경 인허가·법정 측정 성적서\n제출 체계 구축 및 법규 목록\n최신화',
#         '환경',
#         '상',
#         '60일',
#         '현대협력'],
#        ['R-07',
#         '온실가스(Scope1+2) 산정 경계\n정의 후 월별 데이터\n수집(전력/연료) 및 산정표 작성',
#         '환경',
#         '중',
#         '90일',
#         '현대협력'],
#        ['R-08',
#         '부패방지/정보보안 교육 이수율\n100% 달성(미이수자 자동\n알림·재교육) 및 교육 기록 보관',
#         '윤리/보안',
#         '중',
#         '90일',
#         '현대협력'],
#        ['R-09',
#         '2차 협력사 등록-평가-개선조치\n추적 프로세스 수립(평가\n기준·주기·반려 기준 포함)',
#         '공급망',
#         '중',
#         '90일',
#         '현대협력+현대중공업'],
#        ['R-10',
#         '정량\n데이터(에너지/폐기물/교육/사고)\n월별 집계 템플릿 표준화 및 증빙\n업로드 규칙 적용',
#         '데이터 품질',
#         '중',
#         '60일',
#         '현대협력']],
#       'rowCount': 8,
#       'colCount': 6},
#      'table2': {'rows': [['항목ID', '항목', '상태', '사유(예시)', '요청'],
#        ['증빙/데이터(예시)'],
#        ['QN-03',
#         '아차사고 보고 건수',
#         '누락',
#         '보고 체계/기록\n미제출',
#         '아차사고\n보고서(최근\n12개월), 보고\n프로세스 문서'],
#        ['QN-05',
#         '외주/협력 인력\n안전교육 이수율',
#         '누락',
#         '외주 포함 집계 불가',
#         '출입명부+교육이수\n연계 데이터, 외주\n교육대장'],
#        ['QN-07',
#         '온실가스\n배출량(Scope1+2)',
#         '누락',
#         '산정표/활동자료\n미제출',
#         '전력·연료 사용\n데이터, 산정 경계']],
#       'rowCount': 5,
#       'colCount': 5}}},
#    'page6': {'text': '정의, 산정표\nQN-08 용수 사용량 누락 계량/청구서 미제출 수도요금 청구서\n또는 계량기 기록\nQN-11 폐기물 재활용률 불확실 분류별 집계표 부재 폐기물 분류별\n발생/재활용 집계표,\n위탁처리 명세\nQN-13 환경 법규 누락 공식 확인 자료 최근 3년 행정처분\n위반/행정처분 미제출 확인서(없음 포함)\nQN-17 익명 신고 접수 건수 누락 채널 미운영 추정 신고채널 운영\n증빙(URL/전화),\n처리대장(익명화)\nQN-19 협력사 ESG 평가 누락 평가 기록 미제출 평가표, 평가 결과,\n실시 비율 평가 주기·기준\nQN-22 백업 수행 주기 누락 정책/로그 미제출 백업 정책, 백업\n로그, 복구 테스트\n결과\nQN-25 개인정보 파기 기록 누락 파기대장 미제출 파기대장, 파기\n보관율 절차서, 파기\n증빙(스크린샷 등)\n6',
#     'tableCount': 1,
#     'tables': {'table1': {'rows': [['정의, 산정표'],
#        ['QN-08', '용수 사용량', '누락', '계량/청구서 미제출', '수도요금 청구서\n또는 계량기 기록'],
#        ['QN-11',
#         '폐기물 재활용률',
#         '불확실',
#         '분류별 집계표 부재',
#         '폐기물 분류별\n발생/재활용 집계표,\n위탁처리 명세'],
#        ['QN-13',
#         '환경 법규\n위반/행정처분',
#         '누락',
#         '공식 확인 자료\n미제출',
#         '최근 3년 행정처분\n확인서(없음 포함)'],
#        ['QN-17',
#         '익명 신고 접수 건수',
#         '누락',
#         '채널 미운영 추정',
#         '신고채널 운영\n증빙(URL/전화),\n처리대장(익명화)'],
#        ['QN-19',
#         '협력사 ESG 평가\n실시 비율',
#         '누락',
#         '평가 기록 미제출',
#         '평가표, 평가 결과,\n평가 주기·기준'],
#        ['QN-22', '백업 수행 주기', '누락', '정책/로그 미제출', '백업 정책, 백업\n로그, 복구 테스트\n결과'],
#        ['QN-25',
#         '개인정보 파기 기록\n보관율',
#         '누락',
#         '파기대장 미제출',
#         '파기대장, 파기\n절차서, 파기\n증빙(스크린샷 등)']],
#       'rowCount': 8,
#       'colCount': 5}}},
#    'page7': {'text': '2. 진단서\n2.1 진단 개요\n진단 대상 현대협력 (현대중공업 협력사, 샘플)\n진단 범위 인권·노동 / 안전보건 / 환경 / 윤리·컴플라이언스\n/ 공급망 관리 / 정보보안·개인정보\n진단 방식 정성(체크리스트) + 정량(지표/수치)\n상태 정의(정성) 충족 / 부분충족 / 미충족 / 미확인\n상태 정의(정량) 확인 / 누락 / 불확실\n근거 유형 정책·절차 문서 / 교육·점검 기록 / 시스템 로그 /\n제3자 인증 / 미제출(확인 불가)\n2.2 정성적 진단(체크리스트)\nN 구분 체크항목 요구수 응답 근거(예시) 비고\no 준\n아동노동 금지 정책 및 계약서\n1 인권·노동 필수 충족 인권정책 v1.0 -\n반영\n강제노동 금지(채무노동 포함) 부분충 해외근로자 증빙\n2 인권·노동 필수 채용절차서 일부\n확인 절차 족 미흡\n차별·괴롭힘 금지 및 신고채널 익명 제보/보호\n3 인권·노동 필수 미충족 미제출\n운영 절차 부재\n근로시간·휴게시간 준수(법정 부분충 초과근로 관리\n4 인권·노동 필수 근태기록 일부\n기준) 족 미흡\n5 인권·노동 임금·수당 지급 및 체불 방지 필수 충족 급여대장(샘플) -\n이주노동자(해당 시) 권리 해당 여부 확인\n6 인권·노동 권장 미확인 미제출\n보호(계약·언어) 필요\n협력업체(2차) 인권 리스크 평가 체계 확인\n7 인권·노동 권장 미확인 미제출\n평가 불가\n부분충\n8 안전보건 안전보건 방침/목표(KPI) 수립 필수 안전보건 계획서 정량 KPI 부족\n족\n정기 위험성평가 실시 및 부분충 위험성평가표(일\n9 안전보건 필수 이행 증빙 부족\n개선조치 기록 족 부)\n7',
#     'tableCount': 2,
#     'tables': {'table1': {'rows': [['현대협력 (현대중공업 협력사, 샘플)'],
#        ['진단 대상'],
#        ['인권·노동 / 안전보건 / 환경 / 윤리·컴플라이언스\n/ 공급망 관리 / 정보보안·개인정보'],
#        ['진단 범위'],
#        ['정성(체크리스트) + 정량(지표/수치)'],
#        ['진단 방식'],
#        ['충족 / 부분충족 / 미충족 / 미확인'],
#        ['상태 정의(정성)'],
#        ['확인 / 누락 / 불확실'],
#        ['상태 정의(정량)'],
#        ['정책·절차 문서 / 교육·점검 기록 / 시스템 로그 /\n제3자 인증 / 미제출(확인 불가)'],
#        ['근거 유형']],
#       'rowCount': 12,
#       'colCount': 1},
#      'table2': {'rows': [['N', '구분', '체크항목', '요구수', '응답', '근거(예시)', '비고'],
#        ['o', '준'],
#        ['1', '인권·노동', '아동노동 금지 정책 및 계약서\n반영', '필수', '충족', '인권정책 v1.0', '-'],
#        ['2',
#         '인권·노동',
#         '강제노동 금지(채무노동 포함)\n확인 절차',
#         '필수',
#         '부분충\n족',
#         '채용절차서 일부',
#         '해외근로자 증빙\n미흡'],
#        ['3',
#         '인권·노동',
#         '차별·괴롭힘 금지 및 신고채널\n운영',
#         '필수',
#         '미충족',
#         '미제출',
#         '익명 제보/보호\n절차 부재'],
#        ['4',
#         '인권·노동',
#         '근로시간·휴게시간 준수(법정\n기준)',
#         '필수',
#         '부분충\n족',
#         '근태기록 일부',
#         '초과근로 관리\n미흡'],
#        ['5', '인권·노동', '임금·수당 지급 및 체불 방지', '필수', '충족', '급여대장(샘플)', '-'],
#        ['6',
#         '인권·노동',
#         '이주노동자(해당 시) 권리\n보호(계약·언어)',
#         '권장',
#         '미확인',
#         '미제출',
#         '해당 여부 확인\n필요'],
#        ['7',
#         '인권·노동',
#         '협력업체(2차) 인권 리스크\n평가',
#         '권장',
#         '미확인',
#         '미제출',
#         '평가 체계 확인\n불가'],
#        ['8',
#         '안전보건',
#         '안전보건 방침/목표(KPI) 수립',
#         '필수',
#         '부분충\n족',
#         '안전보건 계획서',
#         '정량 KPI 부족'],
#        ['9',
#         '안전보건',
#         '정기 위험성평가 실시 및\n개선조치 기록',
#         '필수',
#         '부분충\n족',
#         '위험성평가표(일\n부)',
#         '이행 증빙 부족']],
#       'rowCount': 11,
#       'colCount': 7}}},
#    'page8': {'text': '10 안전보건 보호구(PPE) 지급·착용 관리 필수 충족 PPE 지급대장 -\n산업재해·아차사고 조사보고서/절차\n11 안전보건 필수 미충족 미제출\n보고/재발방지 프로세스 부재\n부분충 현장 적용 범위\n12 안전보건 작업허가서(Hot work 등) 운영 필수 작업허가서(일부)\n족 불명\n부분충 교육이수 외주 이수율\n13 안전보건 협력사/외주 작업자 안전교육 필수\n족 명단(일부) 미확인\n비상대응(화재/누출) 훈련 및 부분충 훈련 기록\n14 안전보건 권장 소방점검표\n점검 족 불완전\n화학물질 누출 대응 절차 및 부분충 누출키트 점검\n15 안전보건 필수 MSDS 일부\n장비 족 기록 부족\n환경경영 방침 및 법규 준수 부분충 법규 목록\n16 환경 필수 환경관리지침\n체계 족 최신화 필요\n유해화학물질(보관/취급/누출 부분충 창고 점검 기록\n17 환경 필수 MSDS 목록(일부)\n대응) 관리 족 부족\n폐기물 분리배출 및 위탁처리 폐기물\n18 환경 필수 충족 -\n증빙 인계서(샘플)\n대기/수질/소음 인허가·측정 측정성적서\n19 환경 필수 미확인 미제출\n기록 미제출\n비상시 환경사고 계획서 확인\n20 환경 권장 미확인 미제출\n대응(유출/오염) 계획 불가\n에너지 사용량 모니터링(월별 부분충\n21 환경 권장 전력고지서(일부) 월별 집계 미흡\n집계) 족\n윤리·컴플라이언 부패방지 부분충 승인/기록 절차\n22 필수 윤리규정\n스 정책(금품/접대/리베이트) 족 부족\n윤리·컴플라이언\n23 이해상충 신고 및 관리 권장 미확인 미제출 제도 확인 불가\n스\n2차 협력사 등록·평가·개선 부분충 평가 기준/주기\n24 공급망 권장 협력사 목록\n프로세스 족 미정\n정보보안·개인정 보안사고 대응/백업/랜섬웨어 사고대응·백업정\n25 필수 미충족 미제출\n보 대비 책 부재\n정성 요약(3 줄 이내)\n• 익명 신고채널 및 신고자 보호 절차를 지키지 않음.\n• 산업재해·아차사고 조사 및 재발방지 프로세스를 지키지 않음.\n8',
#     'tableCount': 1,
#     'tables': {'table1': {'rows': [['10',
#         '안전보건',
#         '보호구(PPE) 지급·착용 관리',
#         '필수',
#         '충족',
#         'PPE 지급대장',
#         '-'],
#        ['11',
#         '안전보건',
#         '산업재해·아차사고\n보고/재발방지 프로세스',
#         '필수',
#         '미충족',
#         '미제출',
#         '조사보고서/절차\n부재'],
#        ['12',
#         '안전보건',
#         '작업허가서(Hot work 등) 운영',
#         '필수',
#         '부분충\n족',
#         '작업허가서(일부)',
#         '현장 적용 범위\n불명'],
#        ['13',
#         '안전보건',
#         '협력사/외주 작업자 안전교육',
#         '필수',
#         '부분충\n족',
#         '교육이수\n명단(일부)',
#         '외주 이수율\n미확인'],
#        ['14',
#         '안전보건',
#         '비상대응(화재/누출) 훈련 및\n점검',
#         '권장',
#         '부분충\n족',
#         '소방점검표',
#         '훈련 기록\n불완전'],
#        ['15',
#         '안전보건',
#         '화학물질 누출 대응 절차 및\n장비',
#         '필수',
#         '부분충\n족',
#         'MSDS 일부',
#         '누출키트 점검\n기록 부족'],
#        ['16',
#         '환경',
#         '환경경영 방침 및 법규 준수\n체계',
#         '필수',
#         '부분충\n족',
#         '환경관리지침',
#         '법규 목록\n최신화 필요'],
#        ['17',
#         '환경',
#         '유해화학물질(보관/취급/누출\n대응) 관리',
#         '필수',
#         '부분충\n족',
#         'MSDS 목록(일부)',
#         '창고 점검 기록\n부족'],
#        ['18', '환경', '폐기물 분리배출 및 위탁처리\n증빙', '필수', '충족', '폐기물\n인계서(샘플)', '-'],
#        ['19', '환경', '대기/수질/소음 인허가·측정\n기록', '필수', '미확인', '미제출', '측정성적서\n미제출'],
#        ['20',
#         '환경',
#         '비상시 환경사고\n대응(유출/오염) 계획',
#         '권장',
#         '미확인',
#         '미제출',
#         '계획서 확인\n불가'],
#        ['21',
#         '환경',
#         '에너지 사용량 모니터링(월별\n집계)',
#         '권장',
#         '부분충\n족',
#         '전력고지서(일부)',
#         '월별 집계 미흡'],
#        ['22',
#         '윤리·컴플라이언\n스',
#         '부패방지\n정책(금품/접대/리베이트)',
#         '필수',
#         '부분충\n족',
#         '윤리규정',
#         '승인/기록 절차\n부족'],
#        ['23', '윤리·컴플라이언\n스', '이해상충 신고 및 관리', '권장', '미확인', '미제출', '제도 확인 불가'],
#        ['24',
#         '공급망',
#         '2차 협력사 등록·평가·개선\n프로세스',
#         '권장',
#         '부분충\n족',
#         '협력사 목록',
#         '평가 기준/주기\n미정'],
#        ['25',
#         '정보보안·개인정\n보',
#         '보안사고 대응/백업/랜섬웨어\n대비',
#         '필수',
#         '미충족',
#         '미제출',
#         '사고대응·백업정\n책 부재']],
#       'rowCount': 16,
#       'colCount': 7}}},
#    'page9': {'text': '• 보안사고 대응 및 백업 정책(랜섬웨어 대비)을 지키지 않음.\n2.3 정량적 진단(지표/수치)\n항목ID 진단 항목 단위 상태 결과(예시) 기준/요구 근거(예시) 비고\nQN-01 총 근로자 수 명 확인 180 - 인사현황표(샘플) -\n최근 12개월 0건\nQN-02 건 불확실 2 산재보고(미제출) 구두 확인\n산업재해 건수 목표(권장)\n최근 12개월 월 1건\n보고 체계\nQN-03 아차사고 보고 건 누락 - 이상 미제출\n부재 가능\n건수 보고(권장)\n정기 안전교육 연 8시간 외주 포함\nQN-04 시간/인 확인 4.5 교육대장(일부)\n평균 이수시간 이상(예시) 필요\n외주/협력 인력 출입/교육\nQN-05 % 누락 - 100% 미제출\n안전교육 이수율 연동 필요\n전기요금 월별 집계\nQN-06 전력 사용량(연간) MWh 불확실 1,250 -\n고지서(일부) 필요\n온실가스\n산정 및 산정 경계\nQN-07 배출량(Scope tCO2e 누락 - 미제출\n보고(권장) 설정 필요\n1+2)\n계량기/청구서\nQN-08 연간 용수 사용량 톤 누락 - - 미제출\n필요\n전년 대비\nQN-09 일반폐기물 발생량 톤/년 확인 48 인계서(샘플) -\n감축(권장)\nQN-10 지정폐기물 발생량 톤/년 확인 6.2 법정 준수 인계서(샘플) -\n70% 분류 체계\nQN-11 폐기물 재활용률 % 불확실 62 집계표(미제출)\n이상(예시) 필요\n유해화학물질 취급 명단/주기\nQN-12 % 불확실 80 100% 교육기록(일부)\n교육 이수율 확인 필요\n환경 법규\n공식 확인\nQN-13 위반/행정처분 건 누락 - 0건 미제출\n필요\n건수(최근 3년)\n부패방지 교육 교육이수\nQN-14 % 확인 60 100% -\n이수율 기록(샘플)\n윤리/컴플라이언스 신규/협력사\nQN-15 % 확인 70 100% 서약서(일부)\n서약서 징구율 포함 필요\nQN-16 내부 점검(감사) 회 불확실 1 2회 점검보고(미제출) 체계화 필요\n9',
#     'tableCount': 1,
#     'tables': {'table1': {'rows': [['항목ID',
#         '진단 항목',
#         '단위',
#         '상태',
#         '결과(예시)',
#         '기준/요구',
#         '근거(예시)',
#         '비고'],
#        ['QN-01', '총 근로자 수', '명', '확인', '180', '-', '인사현황표(샘플)', '-'],
#        ['QN-02',
#         '최근 12개월\n산업재해 건수',
#         '건',
#         '불확실',
#         '2',
#         '0건\n목표(권장)',
#         '산재보고(미제출)',
#         '구두 확인'],
#        ['QN-03',
#         '최근 12개월\n아차사고 보고\n건수',
#         '건',
#         '누락',
#         '-',
#         '월 1건\n이상\n보고(권장)',
#         '미제출',
#         '보고 체계\n부재 가능'],
#        ['QN-04',
#         '정기 안전교육\n평균 이수시간',
#         '시간/인',
#         '확인',
#         '4.5',
#         '연 8시간\n이상(예시)',
#         '교육대장(일부)',
#         '외주 포함\n필요'],
#        ['QN-05',
#         '외주/협력 인력\n안전교육 이수율',
#         '%',
#         '누락',
#         '-',
#         '100%',
#         '미제출',
#         '출입/교육\n연동 필요'],
#        ['QN-06',
#         '전력 사용량(연간)',
#         'MWh',
#         '불확실',
#         '1,250',
#         '-',
#         '전기요금\n고지서(일부)',
#         '월별 집계\n필요'],
#        ['QN-07',
#         '온실가스\n배출량(Scope\n1+2)',
#         'tCO2e',
#         '누락',
#         '-',
#         '산정 및\n보고(권장)',
#         '미제출',
#         '산정 경계\n설정 필요'],
#        ['QN-08', '연간 용수 사용량', '톤', '누락', '-', '-', '미제출', '계량기/청구서\n필요'],
#        ['QN-09',
#         '일반폐기물 발생량',
#         '톤/년',
#         '확인',
#         '48',
#         '전년 대비\n감축(권장)',
#         '인계서(샘플)',
#         '-'],
#        ['QN-10', '지정폐기물 발생량', '톤/년', '확인', '6.2', '법정 준수', '인계서(샘플)', '-'],
#        ['QN-11',
#         '폐기물 재활용률',
#         '%',
#         '불확실',
#         '62',
#         '70%\n이상(예시)',
#         '집계표(미제출)',
#         '분류 체계\n필요'],
#        ['QN-12',
#         '유해화학물질 취급\n교육 이수율',
#         '%',
#         '불확실',
#         '80',
#         '100%',
#         '교육기록(일부)',
#         '명단/주기\n확인 필요'],
#        ['QN-13',
#         '환경 법규\n위반/행정처분\n건수(최근 3년)',
#         '건',
#         '누락',
#         '-',
#         '0건',
#         '미제출',
#         '공식 확인\n필요'],
#        ['QN-14', '부패방지 교육\n이수율', '%', '확인', '60', '100%', '교육이수\n기록(샘플)', '-'],
#        ['QN-15',
#         '윤리/컴플라이언스\n서약서 징구율',
#         '%',
#         '확인',
#         '70',
#         '100%',
#         '서약서(일부)',
#         '신규/협력사\n포함 필요'],
#        ['QN-16', '내부 점검(감사)', '회', '불확실', '1', '2회', '점검보고(미제출)', '체계화 필요']],
#       'rowCount': 17,
#       'colCount': 8}}},
#    'page10': {'text': '수행 횟수(연간) 이상(예시)\n익명 신고 접수 채널 채널 미운영\nQN-17 건 누락 - 미제출\n건수(연간) 운영(필수) 추정\n협력사(2차) 등록\nQN-18 개 확인 35 - 협력사 리스트 -\n수\n협력사 ESG 평가 평가기준/주기\nQN-19 % 누락 - 100%(권장) 미제출\n실시 비율 필요\n협력사 개선조치 80%\nQN-20 % 누락 - 미제출 추적관리 필요\n완료율 이상(예시)\n정보보안 교육 전사 확대\nQN-21 % 불확실 50 100% 교육기록(일부)\n이수율 필요\n주 1회 정책/로그\nQN-22 백업 수행 주기 회/주 누락 - 미제출\n이상(예시) 필요\n접근권한 점검 분기 승인·이력\nQN-23 회/년 불확실 1 권한표(일부)\n주기 1회(예시) 필요\n개인정보\n시스템\nQN-24 처리시스템 보유 Y/N 확인 Y - -\n목록(샘플)\n여부\n개인정보 파기\nQN-25 % 누락 - 100% 미제출 파기대장 필요\n기록 보관율\n10',
#     'tableCount': 1,
#     'tables': {'table1': {'rows': [['수행 횟수(연간)', '이상(예시)'],
#        ['QN-17',
#         '익명 신고 접수\n건수(연간)',
#         '건',
#         '누락',
#         '-',
#         '채널\n운영(필수)',
#         '미제출',
#         '채널 미운영\n추정'],
#        ['QN-18', '협력사(2차) 등록\n수', '개', '확인', '35', '-', '협력사 리스트', '-'],
#        ['QN-19',
#         '협력사 ESG 평가\n실시 비율',
#         '%',
#         '누락',
#         '-',
#         '100%(권장)',
#         '미제출',
#         '평가기준/주기\n필요'],
#        ['QN-20',
#         '협력사 개선조치\n완료율',
#         '%',
#         '누락',
#         '-',
#         '80%\n이상(예시)',
#         '미제출',
#         '추적관리 필요'],
#        ['QN-21',
#         '정보보안 교육\n이수율',
#         '%',
#         '불확실',
#         '50',
#         '100%',
#         '교육기록(일부)',
#         '전사 확대\n필요'],
#        ['QN-22',
#         '백업 수행 주기',
#         '회/주',
#         '누락',
#         '-',
#         '주 1회\n이상(예시)',
#         '미제출',
#         '정책/로그\n필요'],
#        ['QN-23',
#         '접근권한 점검\n주기',
#         '회/년',
#         '불확실',
#         '1',
#         '분기\n1회(예시)',
#         '권한표(일부)',
#         '승인·이력\n필요'],
#        ['QN-24',
#         '개인정보\n처리시스템 보유\n여부',
#         'Y/N',
#         '확인',
#         'Y',
#         '-',
#         '시스템\n목록(샘플)',
#         '-'],
#        ['QN-25', '개인정보 파기\n기록 보관율', '%', '누락', '-', '100%', '미제출', '파기대장 필요']],
#       'rowCount': 10,
#       'colCount': 8}}}}}}

# %%
# csv 테스트
path = "C:/Users/User/Downloads/Steel_industry_data.csv"
test_result = handle_file(path)
test_result
# Out:
# {'kind': 'CSV',
#  'ext': 'csv',
#  'dataframe':                   癤풼ate  Usage_kWh  Lagging_Current_Reactive.Power_kVarh  \
#  0      01/01/2018 00:15       3.17                                  2.95
#  1      01/01/2018 00:30       4.00                                  4.46
#  2      01/01/2018 00:45       3.24                                  3.28
#  3      01/01/2018 01:00       3.31                                  3.56
#  4      01/01/2018 01:15       3.82                                  4.50
#  ...                 ...        ...                                   ...
#  35035  31/12/2018 23:00       3.85                                  4.86
#  35036  31/12/2018 23:15       3.74                                  3.74
#  35037  31/12/2018 23:30       3.78                                  3.17
#  35038  31/12/2018 23:45       3.78                                  3.06
#  35039  31/12/2018 00:00       3.67                                  3.02
#
#         Leading_Current_Reactive_Power_kVarh  CO2(tCO2)  \
#  0                                      0.00        0.0
#  1                                      0.00        0.0
#  2                                      0.00        0.0
#  3                                      0.00        0.0
#  4                                      0.00        0.0
#  ...                                     ...        ...
#  35035                                  0.00        0.0
#  35036                                  0.00        0.0
#  35037                                  0.07        0.0
#  35038                                  0.11        0.0
#  35039                                  0.07        0.0
#
#         Lagging_Current_Power_Factor  Leading_Current_Power_Factor    NSM  \
#  0                             73.21                        100.00    900
#  1                             66.77                        100.00   1800
#  2                             70.28                        100.00   2700
#  3                             68.09                        100.00   3600
#  4                             64.72                        100.00   4500
#  ...                             ...                           ...    ...
#  35035                         62.10                        100.00  82800
#  35036                         70.71                        100.00  83700
#  35037                         76.62                         99.98  84600
#  35038                         77.72                         99.96  85500
#  35039                         77.22                         99.98      0
#
#        WeekStatus Day_of_week   Load_Type
#  0        Weekday      Monday  Light_Load
#  1        Weekday      Monday  Light_Load
#  2        Weekday      Monday  Light_Load
#  3        Weekday      Monday  Light_Load
#  4        Weekday      Monday  Light_Load
#  ...          ...         ...         ...
#  35035    Weekday      Monday  Light_Load
#  35036    Weekday      Monday  Light_Load
#  35037    Weekday      Monday  Light_Load
#  35038    Weekday      Monday  Light_Load
#  35039    Weekday      Monday  Light_Load
#
#  [35040 rows x 11 columns]}

# %%
# xlsx 테스트
path = "C:/Users/User/Downloads/Steel_industry_data_xlsx.xlsx"
test_result = handle_file(path)
test_result
# Out:
# {'kind': 'EXCEL',
#  'ext': 'xlsx',
#  'dataframe':                    date  Usage_kWh  Lagging_Current_Reactive.Power_kVarh  \
#  0      01/01/2018 00:15       3.17                                  2.95
#  1      01/01/2018 00:30       4.00                                  4.46
#  2      01/01/2018 00:45       3.24                                  3.28
#  3      01/01/2018 01:00       3.31                                  3.56
#  4      01/01/2018 01:15       3.82                                  4.50
#  ...                 ...        ...                                   ...
#  35035  31/12/2018 23:00       3.85                                  4.86
#  35036  31/12/2018 23:15       3.74                                  3.74
#  35037  31/12/2018 23:30       3.78                                  3.17
#  35038  31/12/2018 23:45       3.78                                  3.06
#  35039  31/12/2018 00:00       3.67                                  3.02
#
#         Leading_Current_Reactive_Power_kVarh  CO2(tCO2)  \
#  0                                      0.00        0.0
#  1                                      0.00        0.0
#  2                                      0.00        0.0
#  3                                      0.00        0.0
#  4                                      0.00        0.0
#  ...                                     ...        ...
#  35035                                  0.00        0.0
#  35036                                  0.00        0.0
#  35037                                  0.07        0.0
#  35038                                  0.11        0.0
#  35039                                  0.07        0.0
#
#         Lagging_Current_Power_Factor  Leading_Current_Power_Factor    NSM  \
#  0                             73.21                        100.00    900
#  1                             66.77                        100.00   1800
#  2                             70.28                        100.00   2700
#  3                             68.09                        100.00   3600
#  4                             64.72                        100.00   4500
#  ...                             ...                           ...    ...
#  35035                         62.10                        100.00  82800
#  35036                         70.71                        100.00  83700
#  35037                         76.62                         99.98  84600
#  35038                         77.72                         99.96  85500
#  35039                         77.22                         99.98      0
#
#        WeekStatus Day_of_week   Load_Type
#  0        Weekday      Monday  Light_Load
#  1        Weekday      Monday  Light_Load
#  2        Weekday      Monday  Light_Load
#  3        Weekday      Monday  Light_Load
#  4        Weekday      Monday  Light_Load
#  ...          ...         ...         ...
#  35035    Weekday      Monday  Light_Load
#  35036    Weekday      Monday  Light_Load
#  35037    Weekday      Monday  Light_Load
#  35038    Weekday      Monday  Light_Load
#  35039    Weekday      Monday  Light_Load
#
#  [35040 rows x 11 columns]}

# %%
# jpg 테스트
path = "C:/Users/User/Downloads/성광벤드 ISO 45001_page-0001.jpg"
test_result = handle_file(path)
test_result
# Out:
# {'kind': 'IMAGE',
#  'ext': 'jpg',
#  'content': {'pageCount': 1,
#   'pages': {'page1': {'text': '',
#     'tableCount': 1,
#     'tables': {'table1': {'rows': [], 'rowCount': 0, 'colCount': 0}}}}}}
